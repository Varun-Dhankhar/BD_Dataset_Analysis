# %%
# Import pandas
import pandas as pd
import csv
 
# reading csv file
df2=pd.read_csv("D:/Time-varyying_PF_data/BD_Dataset_RPI_1/06-September-2022.csv")

# %matplotlib notebook

# %%
header=["Timestamp", 'V1','V2', 'V3', 'A1', 'A2', 'A3', 'PA1', 'PA2', 'PA3', 'W1','W2', 'W3', 'VAR1', 'VAR2', 'VAR3', 'VA1', 'VA2', 'VA3', 'F', 'A12', 'A13', 'PF', 'Date', 'Time', 'DWh', 'DVARh', 'RWh', 'RVARh', 'TW', 'TVAR', 'TVA', 'TA', 'V12', 'V23', 'V31', 'THD1', 'THD2', 'THD3', 'THDA1', 'THDA2', 'THDA3', 'PF1', 'PF2', 'PF3']

df2.columns=header

# %%
df2.head()
# Out:
#       Timestamp          V1          V2          V3     A1   A2   A3  \
# 0  1.662394e+09  241.021011  241.001007  242.774017  1.465  0.0  0.0
# 1  1.662394e+09  241.087006  241.176010  242.913010  1.469  0.0  0.0
# 2  1.662394e+09  241.202011  241.303009  242.985016  1.461  0.0  0.0
# 3  1.662394e+09  241.160019  241.200012  242.937012  1.466  0.0  0.0
# 4  1.662394e+09  241.208008  241.236008  243.015015  1.461  0.0  0.0
#
#          PA1  PA2  PA3  ...         V31    THD1    THD2    THD3      THDA1  \
# 0 -26.887499  0.0  0.0  ...  418.979034  1.2236  1.0004  0.9969  53.820999
# 1 -27.038599  0.0  0.0  ...  419.157013  1.2233  1.0000  0.9967  54.181499
# 2 -27.003000  0.0  0.0  ...  419.318024  1.4123  1.2244  0.9966  53.035999
# 3 -26.651299  0.0  0.0  ...  419.240021  1.2232  0.9999  0.9966  53.766998
# 4 -26.864698  0.0  0.0  ...  419.350006  1.2230  0.9998  0.9964  53.286198
#
#    THDA2  THDA3    PF1  PF2  PF3
# 0    0.0    0.0 -0.782 -1.0 -1.0
# 1    0.0    0.0 -0.780 -1.0 -1.0
# 2    0.0    0.0 -0.783 -1.0 -1.0
# 3    0.0    0.0 -0.784 -1.0 -1.0
# 4    0.0    0.0 -0.783 -1.0 -1.0
#
# [5 rows x 45 columns]

# %%
df2.describe()
# Out:
#           Timestamp            V1            V2            V3            A1  \
# count  7.765500e+04  77655.000000  77655.000000  77655.000000  77655.000000
# mean   1.662437e+09    240.320665    240.615829    242.474285      1.359972
# std    2.492167e+04      1.125561      1.072777      1.051000      0.138208
# min    1.662394e+09    236.337006    236.455017    238.316010      1.156000
# 25%    1.662415e+09    239.554016    239.976013    241.839005      1.193000
# 50%    1.662437e+09    240.384018    240.669006    242.520004      1.456000
# 75%    1.662458e+09    240.877014    241.098007    243.045013      1.475000
# max    1.662480e+09    243.884018    244.100006    245.645004      1.532000
#
#             A2       A3           PA1      PA2      PA3  ...           V31  \
# count  77655.0  77655.0  77655.000000  77655.0  77655.0  ...  77655.000000
# mean       0.0      0.0    -28.829664      0.0      0.0  ...    418.113050
# std        0.0      0.0      2.328600      0.0      0.0  ...      1.869952
# min        0.0      0.0    -32.560799      0.0      0.0  ...    411.062012
# 25%        0.0      0.0    -31.615499      0.0      0.0  ...    416.893509
# 50%        0.0      0.0    -27.241899      0.0      0.0  ...    418.244019
# 75%        0.0      0.0    -26.862099      0.0      0.0  ...    419.048035
# max        0.0      0.0    -26.009499      0.0      0.0  ...    423.935028
#
#                THD1          THD2          THD3         THDA1    THDA2  \
# count  77655.000000  77655.000000  77655.000000  77655.000000  77655.0
# mean       1.151925      0.986173      0.891549     46.206692      0.0
# std        0.135709      0.124516      0.158163      9.568193      0.0
# min        0.704600      0.704700      0.000000     32.513000      0.0
# 25%        1.001500      0.999500      0.706000     34.695499      0.0
# 50%        1.223100      1.001000      0.995800     52.300999      0.0
# 75%        1.226500      1.002900      0.997900     54.459099      0.0
# max        1.420500      1.234000      1.227500     57.843998      0.0
#
#          THDA3           PF1      PF2      PF3
# count  77655.0  77655.000000  77655.0  77655.0
# mean       0.0     -0.790466     -1.0     -1.0
# std        0.0      0.011541      0.0      0.0
# min        0.0     -0.812000     -1.0     -1.0
# 25%        0.0     -0.803000     -1.0     -1.0
# 50%        0.0     -0.787000     -1.0     -1.0
# 75%        0.0     -0.780000     -1.0     -1.0
# max        0.0     -0.769000     -1.0     -1.0
#
# [8 rows x 45 columns]

# %% [markdown]
# # Preprocessing

# %%
dfp2=df2.copy()

# %%
import datetime


dfp2['Time'] = pd.to_datetime(df2['Timestamp'], unit='s', utc=False)
#dfp= dfp['Meter_Time'].dt.strftime('%d/%m/%Y %H:%M:%S')
#dfp['Date'] = pd.to_datetime(df1.Meter_Time, unit='s')
#dfp['Date']=dfp.Date.dt.strftime('%d/%m/%Y %H:%M:%S')

dfp2['Time']=dfp2['Time'].dt.tz_localize('UTC').dt.tz_convert('Asia/Singapore')

dfp2['Time']= dfp2['Time'].dt.strftime('%d/%m/%Y %H:%M:%S')
dfp2[['Date','Time']]=dfp2['Time'].str.split(' ', 1, expand=True)
dfp2.columns
# Out:
# Index(['Timestamp', 'V1', 'V2', 'V3', 'A1', 'A2', 'A3', 'PA1', 'PA2', 'PA3',
#        'W1', 'W2', 'W3', 'VAR1', 'VAR2', 'VAR3', 'VA1', 'VA2', 'VA3', 'F',
#        'A12', 'A13', 'PF', 'Date', 'Time', 'DWh', 'DVARh', 'RWh', 'RVARh',
#        'TW', 'TVAR', 'TVA', 'TA', 'V12', 'V23', 'V31', 'THD1', 'THD2', 'THD3',
#        'THDA1', 'THDA2', 'THDA3', 'PF1', 'PF2', 'PF3'],
#       dtype='object')

# %%
#2
dfp2=dfp2.drop(columns=['Date'])
df8c2=dfp2['Time']
df9c2=dfp2['Timestamp']
dfp2=dfp2.drop(columns=['Timestamp', 'Time']).astype('float')
dfp2['Timestamp']=df9c2
dfp2['Time']=df8c2

# %%
dfp2['minutes']=dfp2['Time'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1])+ (1/60)*int(x[2]))
dfp2['minutes']
# Out:
# 0           0.033333
# 1           0.050000
# 2           0.066667
# 3           0.083333
# 4           0.100000
#             ...
# 77650    1439.916667
# 77651    1439.933333
# 77652    1439.950000
# 77653    1439.966667
# 77654    1439.983333
# Name: minutes, Length: 77655, dtype: float64

# %% [markdown]
# # Seeing the signals

# %%
dfp2.plot(x='minutes', y=["PF1"],  figsize=(10,4))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='minutes'>

# %%
dfp2.plot(x='minutes', y=["A1"],  figsize=(10,4))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='minutes'>

# %%
dfp2.plot(x='Time', y=["W1"],  figsize=(10,4))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='Time'>

# %%
dfp2['Power-rms'] = dfp2['A1']*dfp2['V1']

# %%
dfp2.plot(x='Time', y=["Power-rms"],  figsize=(10,4))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='Time'>

# %% [markdown]
# # Demeaning the signals

# %%
df_1=dfp2[(dfp2['minutes']>=0) & (dfp2['minutes']<=360)]

# %%
a=df_1['A1'].mean()

# %%
df_1['demean-A1']=df_1['A1']-a
# Out:
# C:\Users\Varun Dhankhar\AppData\Local\Temp\ipykernel_24016\699502963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['demean-A1']=df_1['A1']-a

# %%
df_1.plot(x='minutes', y=["demean-A1"],  figsize=(10,4))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='minutes'>

# %% [markdown]
# # FFT Plot

# %%
# %matplotlib inline
# %matplotlib notebook
import matplotlib.pyplot as plt2
import pandas as pd
import numpy as np


data = df_1['demean-A1'].astype(float).values

N = data.shape[0] #number of elements
t = np.linspace(0, N) #converting minutes to seconds
s = data

fft = np.fft.fft(s)
fftfreq = np.fft.fftfreq(len(s))

T = t[1] - t[0]

f = np.linspace(0, 1 / T, N)
plt2.figure(figsize = (10, 6))
plt2.ylabel("Amplitude")
plt2.xlabel("Frequency [Hz]")
plt2.figure(1)
plt2.plot(fftfreq, np.abs(fft))
plt2.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
