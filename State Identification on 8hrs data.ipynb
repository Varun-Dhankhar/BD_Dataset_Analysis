# %%
# Import pandas
import pandas as pd
import csv
 
# reading csv file
df2=pd.read_csv("D:/Time-varyying_PF_data/06-December-2022.csv")

# %matplotlib notebook

# %%
header=["Timestamp", 'V1','V2', 'V3', 'A1', 'A2', 'A3', 'PA1', 'PA2', 'PA3', 'W1','W2', 'W3', 'VAR1', 'VAR2', 'VAR3', 'VA1', 'VA2', 'VA3', 'F', 'A12', 'A13', 'PF', 'Date', 'Time', 'DWh', 'DVARh', 'RWh', 'RVARh', 'TW', 'TVAR', 'TVA', 'TA', 'V12', 'V23', 'V31', 'THD1', 'THD2', 'THD3', 'THDA1', 'THDA2', 'THDA3', 'PF1', 'PF2', 'PF3']

df2.columns=header

# %%
df2.head()
# Out:
#       Timestamp          V1          V2          V3     A1   A2   A3  \
# 0  1.670256e+09  243.218018  242.887009  244.529007  0.756  0.0  0.0
# 1  1.670256e+09  243.405014  243.080017  244.698013  0.765  0.0  0.0
# 2  1.670256e+09  243.399017  243.074005  244.692017  0.767  0.0  0.0
# 3  1.670256e+09  243.477005  243.140015  244.764008  0.752  0.0  0.0
# 4  1.670256e+09  243.495010  243.158005  244.782013  0.768  0.0  0.0
#
#          PA1  PA2  PA3  ...         V31    THD1    THD2    THD3      THDA1  \
# 0  53.709499  0.0  0.0  ...  422.402008  1.4081  1.2196  1.2164  81.109200
# 1  52.692799  0.0  0.0  ...  422.710022  1.4076  1.2192  1.2160  80.183701
# 2  52.414299  0.0  0.0  ...  422.699005  1.4076  1.2192  1.2160  81.308098
# 3  53.677597  0.0  0.0  ...  422.830017  1.4074  1.2190  0.9927  80.630798
# 4  53.118797  0.0  0.0  ...  422.861023  1.4073  1.2190  1.2158  81.013100
#
#    THDA2  THDA3    PF1  PF2  PF3
# 0    0.0    0.0  0.456 -1.0 -1.0
# ...

# %%
df2.describe()
# Out:
#           Timestamp            V1            V2            V3            A1  \
# count  7.749000e+04  77490.000000  77490.000000  77490.000000  77490.000000
# mean   1.670299e+09    240.780945    240.823578    242.431922      0.820133
# std    2.494041e+04      1.616660      1.463247      1.408713      0.085091
# min    1.670256e+09    236.455017    236.155014    238.306015      0.701000
# 25%    1.670278e+09    239.517014    239.696014    241.375015      0.763000
# 50%    1.670299e+09    240.620010    240.707016    242.249008      0.773000
# 75%    1.670321e+09    242.193008    242.056015    243.648010      0.890000
# max    1.670342e+09    244.261017    244.067017    245.536011      1.069000
#
#             A2       A3           PA1      PA2      PA3  ...           V31  \
# count  77490.0  77490.0  77490.000000  77490.0  77490.0  ...  77490.000000
# mean       0.0      0.0     49.436533      0.0      0.0  ...    418.474985
# ...

# %% [markdown]
# # Preprocessing

# %%
dfp2=df2.copy()

# %%
import datetime


dfp2['Time'] = pd.to_datetime(df2['Timestamp'], unit='s', utc=False)
#dfp= dfp['Meter_Time'].dt.strftime('%d/%m/%Y %H:%M:%S')
#dfp['Date'] = pd.to_datetime(df1.Meter_Time, unit='s')
#dfp['Date']=dfp.Date.dt.strftime('%d/%m/%Y %H:%M:%S')

dfp2['Time']=dfp2['Time'].dt.tz_localize('UTC').dt.tz_convert('Asia/Singapore')

dfp2['Time']= dfp2['Time'].dt.strftime('%d/%m/%Y %H:%M:%S')
dfp2[['Date','Time']]=dfp2['Time'].str.split(' ', 1, expand=True)
dfp2.columns
# Out:
# Index(['Timestamp', 'V1', 'V2', 'V3', 'A1', 'A2', 'A3', 'PA1', 'PA2', 'PA3',
#        'W1', 'W2', 'W3', 'VAR1', 'VAR2', 'VAR3', 'VA1', 'VA2', 'VA3', 'F',
#        'A12', 'A13', 'PF', 'Date', 'Time', 'DWh', 'DVARh', 'RWh', 'RVARh',
#        'TW', 'TVAR', 'TVA', 'TA', 'V12', 'V23', 'V31', 'THD1', 'THD2', 'THD3',
#        'THDA1', 'THDA2', 'THDA3', 'PF1', 'PF2', 'PF3'],
#       dtype='object')

# %%
#2
dfp2=dfp2.drop(columns=['Date'])
df8c2=dfp2['Time']
df9c2=dfp2['Timestamp']
dfp2=dfp2.drop(columns=['Timestamp', 'Time']).astype('float')
dfp2['Timestamp']=df9c2
dfp2['Time']=df8c2

dfp2['minutes']=dfp2['Time'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1])+ (1/60)*int(x[2]))
dfp2['minutes']

# %%
dfp2['minutes']=dfp2['Time'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1])+ (1/60)*int(x[2]))
dfp2['minutes']
# Out:
# 0           0.033333
# 1           0.050000
# 2           0.066667
# 3           0.083333
# 4           0.116667
#             ...
# 77485    1439.916667
# 77486    1439.933333
# 77487    1439.950000
# 77488    1439.966667
# 77489    1439.983333
# Name: minutes, Length: 77490, dtype: float64

# %%
df_1=dfp2.copy()#dfp2[(dfp2['minutes']>=621.6) & (dfp2['minutes']<=1075.56)]

# %%
a=df_1['A1'].mean()
df_1['demean-A1']=df_1['A1']-a

# %% [markdown]
# #  Rolling Average

# %%
df_1["rolling_average_minutely"] = df_1["A1"].rolling(window=60, min_periods=1).mean()

# %%
df_1["rolling_average_minutely"]
# Out:
# 0        0.756000
# 1        0.760500
# 2        0.762667
# 3        0.760000
# 4        0.761600
#            ...
# 77485    0.768050
# 77486    0.768067
# 77487    0.767817
# 77488    0.767867
# 77489    0.767983
# Name: rolling_average_minutely, Length: 77490, dtype: float64

# %% [markdown]
# We have nearly 60 observations in a minute so taking window of 60

# %%
df_1[[
    "A1",
    "rolling_average_minutely",
    ]].plot(color=['maroon', 'gold'],
            )
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
df_1[[
    "rolling_average_minutely",
    ]].plot(color='gold',
            # xlim=["2012-11-11", "2012-11-12"],
           )
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
df_2=dfp2[(dfp2['minutes']>=621.6) & (dfp2['minutes']<=1075.56)]

# %%
df_2["rolling_average_minutely"] = df_2["A1"].rolling(window=60, min_periods=1).mean()
# Out:
# C:\Users\Varun Dhankhar\AppData\Local\Temp\ipykernel_16328\2414828690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2["rolling_average_minutely"] = df_2["A1"].rolling(window=60, min_periods=1).mean()

# %%
df_2[[
    "rolling_average_minutely",
    ]].plot(color='gold',
            # xlim=["2012-11-11", "2012-11-12"],
           )
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
import datetime


df_2['Time'] = pd.to_datetime(df_2['Timestamp'], unit='s', utc=False)
df_2['Time']=df_2['Time'].dt.tz_localize('UTC').dt.tz_convert('Asia/Singapore')
# Out:
# C:\Users\Varun Dhankhar\AppData\Local\Temp\ipykernel_16328\2567806670.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Time'] = pd.to_datetime(df_2['Timestamp'], unit='s', utc=False)
# C:\Users\Varun Dhankhar\AppData\Local\Temp\ipykernel_16328\2567806670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Time']=df_2['Time'].dt.tz_localize('UTC').dt.tz_convert('Asia/Singapore')

# %%
df_2['Time']
# Out:
# 33382   2022-12-06 10:21:36.808765440+08:00
# 33383   2022-12-06 10:21:37.864669184+08:00
# 33384   2022-12-06 10:21:38.904400640+08:00
# 33385   2022-12-06 10:21:39.976286720+08:00
# 33386   2022-12-06 10:21:41.016083712+08:00
#                         ...
# 57753   2022-12-06 17:55:29.763994624+08:00
# 57754   2022-12-06 17:55:30.803808768+08:00
# 57755   2022-12-06 17:55:31.859618816+08:00
# 57756   2022-12-06 17:55:32.899480064+08:00
# 57757   2022-12-06 17:55:33.971282944+08:00
# Name: Time, Length: 24376, dtype: datetime64[ns, Asia/Singapore]

# %% [markdown]
# # Change point detection

# %%
# see which to take l1 or rbf

# %%
import ruptures as rpt
col=df_2["rolling_average_minutely"].values

penalty = 3
algo = rpt.Pelt(model="l1").fit(col)
results3 =  algo.predict(pen=penalty)

# %%
df_2=df_2.reset_index()

# %%
# %matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(col)
for i in results3:
    num = col[i-1]
    ax.axvline(x = i, color = 'k', linestyle= "--")
# Out:
# <img src="data:image/png;base64,..." width="979.5555555555555">

# %%
df_2.loc[24375]['rolling_average_minutely']
# Out:
# 0.992416712641716

# %%
results3
# Out:
# [60,
#  1110,
#  2205,
#  2530,
#  2905,
#  3935,
#  4955,
#  5110,
#  6155,
#  7170,
#  7535,
#  7630,
#  8680,
#  9780,
#  10440,
#  10525,
#  11600,
#  12720,
#  12840,
#  13085,
#  14155,
#  15250,
#  15600,
#  16450,
#  17520,
#  18735,
#  19795,
#  20895,
#  20985,
#  21095,
#  22165,
#  23340,
#  24376]

# %%
results=[x - 1 for x in results3]

# %%
results
# Out:
# [59,
#  1109,
#  2204,
#  2529,
#  2904,
#  3934,
#  4954,
#  5109,
#  6154,
#  7169,
#  7534,
#  7629,
#  8679,
#  9779,
#  10439,
#  10524,
#  11599,
#  12719,
#  12839,
#  13084,
#  14154,
#  15249,
#  15599,
#  16449,
#  17519,
#  18734,
#  19794,
#  20894,
#  20984,
#  21094,
#  22164,
#  23339,
#  24375]

# %%
import csv 
fields = ['Start_time', 'end_time', 'duration', 'mean', 'median', 'mode', 'minimum', 'maximum', 'std_dev', 'variance', 'kurtosis', 'skewness', 'energy', 'signal_mag_area'] 
global filename
filename = "state_statistics.csv"

with open(filename, 'a') as csvfile:  # assigning column headers for the file of day1 only.
    writer = csv.writer(csvfile)
    writer.writerow(fields)
csvfile.close()


def write_csv_header(header):
    global filename
    with open(filename, 'a') as f:
        f.write("\n")
        f.write(header)

# %%
def states():
    for value in range(0, len(results)):
        if results[value]!=results[-1]:
            i=results[value]
            j=results[value+1]
            df_copy=df_2.copy()
            data = ""
            start_time=df_2.loc[i]['Timestamp']
            end_time=df_2.loc[j]['Timestamp']
            duration=end_time-start_time
            data=str(start_time)+ "," +str(end_time)+ "," + str(duration)
            df_copy=df_copy[(df_copy['Timestamp']>=start_time) & (df_copy['Timestamp']<=end_time)]
            data=data + "," + str(df_copy['rolling_average_minutely'].mean()) + "," + str(df_copy['rolling_average_minutely'].median()) + "," + str(df_copy['rolling_average_minutely'].mode()[0]) + "," + str(df_copy['rolling_average_minutely'].min()) + "," + str(df_copy['rolling_average_minutely'].max()) + "," + str(df_copy['rolling_average_minutely'].std()) + "," + str(df_copy['rolling_average_minutely'].var()) + "," +  str(df_copy['rolling_average_minutely'].kurtosis()) + "," + str(df_copy['rolling_average_minutely'].skew())+ "," + str(df_copy['rolling_average_minutely'].apply(lambda x: np.sum(x**2)).mean())+ "," +str(df_copy['rolling_average_minutely'].apply(lambda x: np.sum(abs(x))).sum())
            write_csv_header(data)
            print(data)

# %%
min_start=[]
min_end=[]
for value in range(0, len(results)):
    if results[value]!=results[-1]:
        i=results[value]
        j=results[value+1]
        df_copy=df_2.copy()
        min_start.append(df_2.loc[i]['minutes'])
        min_end.append(df_2.loc[j]['minutes'])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
states()
# Out:
# 1670293364.0454795,1670294536.2465718,1172.2010922431946,0.9806253238770455,0.9818833818038305,0.9763833820819855,0.9417333791653315,0.9975000451008479,0.007790546640772533,6.0692616962052194e-05,3.508601714180856,-1.158635640559972,0.9616866606984291,1030.6372153947752
# 1670294536.2465718,1670295760.9637969,1224.717225074768,0.8943213475283476,0.8931167080998421,0.8918500433365504,0.8271167020003001,0.9417333791653315,0.010148707922568423,0.00010299627249760306,13.075026652382276,-0.7584418119696481,0.7999135749427171,980.1761968910694
# 1670295760.9637969,1670296121.6689892,360.7051923274994,0.7721439522498714,0.7680333693822226,0.7665833701690038,0.7661000361045202,0.8271167020003001,0.011411592689244361,0.00013022444770521537,8.193705185377452,2.9310206777524517,0.5963361079822606,251.71892843345802
# ...

# %% [markdown]
# # K-Means clustering with Elbow method

# %%
df_stats=pd.read_csv("state_statistics.csv")

# %%
df_stats
# Out:
#       Start_time      end_time     duration      mean    median      mode  \
# 0   1.670293e+09  1.670295e+09  1172.201092  0.980625  0.981883  0.976383
# 1   1.670295e+09  1.670296e+09  1224.717225  0.894321  0.893117  0.891850
# 2   1.670296e+09  1.670296e+09   360.705192  0.772144  0.768033  0.766583
# 3   1.670296e+09  1.670297e+09   422.007548  0.860671  0.857692  0.856983
# 4   1.670297e+09  1.670298e+09  1185.798839  0.987814  0.989567  0.983767
# 5   1.670298e+09  1.670299e+09  1223.329564  0.897990  0.898217  0.898500
# 6   1.670299e+09  1.670299e+09   189.599846  0.792546  0.774083  0.770733
# 7   1.670299e+09  1.670300e+09  1234.749333  0.988409  0.991825  0.985750
# 8   1.670300e+09  1.670302e+09  1196.741057  0.902391  0.902625  0.902300
# 9   1.670302e+09  1.670302e+09   406.745682  0.780065  0.775567  0.775683
# 10  1.670302e+09  1.670302e+09   103.838496  0.901541  0.903058  0.902950
# 11  1.670302e+09  1.670303e+09  1173.049334  0.995512  0.996583  0.993033
# ...

# %%
dfst=df_stats.copy()
dfst=dfst.drop(['Start_time', 'end_time', 'std_dev', 'variance', 'kurtosis', 'skewness', 'duration', 'energy', 'signal_mag_area'], axis=1)

# %%
dfst
# Out:
#         mean    median      mode   minimum   maximum
# 0   0.980625  0.981883  0.976383  0.941733  0.997500
# 1   0.894321  0.893117  0.891850  0.827117  0.941733
# 2   0.772144  0.768033  0.766583  0.766100  0.827117
# 3   0.860671  0.857692  0.856983  0.813317  0.917667
# 4   0.987814  0.989567  0.983767  0.917667  0.998400
# 5   0.897990  0.898217  0.898500  0.834550  0.946283
# 6   0.792546  0.774083  0.770733  0.770383  0.874750
# 7   0.988409  0.991825  0.985750  0.874750  1.000933
# 8   0.902391  0.902625  0.902300  0.841633  0.946600
# 9   0.780065  0.775567  0.775683  0.771233  0.841633
# 10  0.901541  0.903058  0.902950  0.840033  0.951250
# 11  0.995512  0.996583  0.993033  0.949233  1.006833
# 12  0.902504  0.902483  0.902550  0.841100  0.949233
# 13  0.773906  0.772033  0.772050  0.766617  0.841100
# 14  0.888434  0.891450  0.824533  0.824533  0.937183
# 15  0.991714  0.992883  0.981167  0.937183  1.006517
# 16  0.900377  0.900383  0.899883  0.842767  0.946850
# ...

# %%
scaler = StandardScaler()
X = dfst.values
scaled_x = scaler.fit_transform(X)

# %%
# %matplotlib inline
# %matplotlib notebook

inertias = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300, n_init=12, random_state=0)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)
f3, ax = plt.subplots(figsize=(8, 6))
plt.plot(range(1,11),inertias)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertias')
plt.show()
# Out:
# D:\Study\conda\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning:
#
# KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#
# D:\Study\conda\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning:
#
# KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#
# D:\Study\conda\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning:
#
# KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#
# D:\Study\conda\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning:
#
# ...

# %% [markdown]
# So it seems 4 clusters would be a good choice as after that slope does not changes much i.e. decrease less

# %%
#Initialize our model
kmeans = KMeans(n_clusters=4,init='k-means++',max_iter=300, n_init=12, random_state=0)

# %%
kmeans.fit(X)
# Out:
# D:\Study\conda\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning:
#
# KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
# KMeans(n_clusters=4, n_init=12, random_state=0)

# %%
clusters = kmeans.predict(X)

# %%
clustX = df_stats.copy()
X2=dfst.copy()

# %%
X2["Cluster"] = clusters
clustX["Cluster"] = clusters

# %%
#X2=X2.drop(['Start_time', 'end_time'], axis=1)

# %%
plotX = X2
plotX.columns = X2.columns

# %%
clustX
# Out:
#       Start_time      end_time     duration      mean    median      mode  \
# 0   1.670293e+09  1.670295e+09  1172.201092  0.980625  0.981883  0.976383
# 1   1.670295e+09  1.670296e+09  1224.717225  0.894321  0.893117  0.891850
# 2   1.670296e+09  1.670296e+09   360.705192  0.772144  0.768033  0.766583
# 3   1.670296e+09  1.670297e+09   422.007548  0.860671  0.857692  0.856983
# 4   1.670297e+09  1.670298e+09  1185.798839  0.987814  0.989567  0.983767
# 5   1.670298e+09  1.670299e+09  1223.329564  0.897990  0.898217  0.898500
# 6   1.670299e+09  1.670299e+09   189.599846  0.792546  0.774083  0.770733
# 7   1.670299e+09  1.670300e+09  1234.749333  0.988409  0.991825  0.985750
# 8   1.670300e+09  1.670302e+09  1196.741057  0.902391  0.902625  0.902300
# 9   1.670302e+09  1.670302e+09   406.745682  0.780065  0.775567  0.775683
# 10  1.670302e+09  1.670302e+09   103.838496  0.901541  0.903058  0.902950
# 11  1.670302e+09  1.670303e+09  1173.049334  0.995512  0.996583  0.993033
# ...

# %%
clustXcopy=clustX.copy()

# %%
clustXcopy['min_start'] = np.array(min_start)
clustXcopy['min_end'] = np.array(min_end)

# %%
vald=pd.DataFrame()

# %%
vald['min_start']=clustXcopy['min_start']
vald['min_end']=clustXcopy['min_end']
vald['cluster']=clustXcopy['Cluster']

# %%
vald
# Out:
#       min_start      min_end  cluster
# 0    622.733333   642.266667        2
# 1    642.266667   662.666667        0
# 2    662.666667   668.683333        1
# 3    668.683333   675.716667        3
# 4    675.716667   695.483333        2
# 5    695.483333   715.866667        0
# 6    715.866667   719.033333        1
# 7    719.033333   739.616667        2
# 8    739.616667   759.550000        0
# 9    759.550000   766.333333        1
# 10   766.333333   768.066667        0
# 11   768.066667   787.616667        2
# 12   787.616667   807.866667        0
# 13   807.866667   819.933333        1
# 14   819.933333   821.500000        3
# 15   821.500000   841.116667        2
# 16   841.116667   861.433333        0
# 17   861.433333   863.700000        1
# 18   863.700000   868.166667        3
# 19   868.166667   888.016667        2
# 20   888.016667   908.283333        0
# 21   908.283333   914.600000        1
# 22   914.600000   930.216667        3
# 23   930.216667   949.783333        2
# ...

# %%
manual=[2, 0, 1, 3, 2, 0, 1, 2, 0, 1, 0, 2, 0, 1, 3, 2, 0, 1, 3, 2, 0, 1, 3, 2, 0, 2, 0, 1, 3, 2, 0, 2]

# %%
vald['manual'] = np.array(manual)

# %%
vald
# Out:
#       min_start      min_end  cluster  manual
# 0    622.733333   642.266667        2       2
# 1    642.266667   662.666667        0       0
# 2    662.666667   668.683333        1       1
# 3    668.683333   675.716667        3       3
# 4    675.716667   695.483333        2       2
# 5    695.483333   715.866667        0       0
# 6    715.866667   719.033333        1       1
# 7    719.033333   739.616667        2       2
# 8    739.616667   759.550000        0       0
# 9    759.550000   766.333333        1       1
# 10   766.333333   768.066667        0       0
# 11   768.066667   787.616667        2       2
# 12   787.616667   807.866667        0       0
# 13   807.866667   819.933333        1       1
# 14   819.933333   821.500000        3       3
# 15   821.500000   841.116667        2       2
# 16   841.116667   861.433333        0       0
# 17   861.433333   863.700000        1       1
# 18   863.700000   868.166667        3       3
# ...

# %%
clustXcopy
# Out:
#       Start_time      end_time     duration      mean    median      mode  \
# 0   2.783822e+07  2.783824e+07  1172.201092  0.980625  0.981883  0.976383
# 1   2.783824e+07  2.783826e+07  1224.717225  0.894321  0.893117  0.891850
# 2   2.783826e+07  2.783827e+07   360.705192  0.772144  0.768033  0.766583
# 3   2.783827e+07  2.783828e+07   422.007548  0.860671  0.857692  0.856983
# 4   2.783828e+07  2.783830e+07  1185.798839  0.987814  0.989567  0.983767
# 5   2.783830e+07  2.783832e+07  1223.329564  0.897990  0.898217  0.898500
# 6   2.783832e+07  2.783832e+07   189.599846  0.792546  0.774083  0.770733
# 7   2.783832e+07  2.783834e+07  1234.749333  0.988409  0.991825  0.985750
# 8   2.783834e+07  2.783836e+07  1196.741057  0.902391  0.902625  0.902300
# 9   2.783836e+07  2.783837e+07   406.745682  0.780065  0.775567  0.775683
# 10  2.783837e+07  2.783837e+07   103.838496  0.901541  0.903058  0.902950
# 11  2.783837e+07  2.783839e+07  1173.049334  0.995512  0.996583  0.993033
# ...

# %%
# %matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(col)
for i in results3:
    num = col[i-1]
    ax.axvline(x = i, color = 'k', linestyle= "--")
# Out:
# <img src="data:image/png;base64,..." width="978.6666666666666">

# %% [markdown]
# # Visualising Clusters

# %%
#PCA with two principal components
pca_2d = PCA(n_components=2)

# %%
PCs_2d = pd.DataFrame(pca_2d.fit_transform(plotX.drop(["Cluster"], axis=1)))

# %%
PCs_2d.columns = ["PC1_2d", "PC2_2d"]

# %%
plotX = pd.concat([plotX,PCs_2d], axis=1, join='inner')

# %%
cluster0 = plotX[plotX["Cluster"] == 0]
cluster1 = plotX[plotX["Cluster"] == 1]
cluster2 = plotX[plotX["Cluster"] == 2]
cluster3 = plotX[plotX["Cluster"] == 3]

# %%
# %matplotlib inline
# %matplotlib notebook

#Instructions for building the 2-D plot

#trace1 is for 'Cluster 0'
trace1 = go.Scatter(
                    x = cluster0["PC1_2d"],
                    y = cluster0["PC2_2d"],
                    mode = "markers",
                    name = "Cluster 0",
                    marker = dict(color = 'rgba(255, 128, 255, 0.8)'),
                    text = None)

#trace2 is for 'Cluster 1'
trace2 = go.Scatter(
                    x = cluster1["PC1_2d"],
                    y = cluster1["PC2_2d"],
                    mode = "markers",
                    name = "Cluster 1",
                    marker = dict(color = 'rgba(255, 128, 2, 0.8)'),
                    text = None)

#trace3 is for 'Cluster 2'
trace3 = go.Scatter(
                    x = cluster2["PC1_2d"],
                    y = cluster2["PC2_2d"],
                    mode = "markers",
                    name = "Cluster 2",
                    marker = dict(color = 'rgba(0, 255, 200, 0.8)'),
                    text = None)

trace4 = go.Scatter(
                    x = cluster3["PC1_2d"],
                    y = cluster3["PC2_2d"],
                    mode = "markers",
                    name = "Cluster 3",
                    marker = dict(color = 'rgba(50, 50, 200, 0.8)'),
                    text = None)

data = [trace1, trace2, trace3, trace4]

title = "Visualizing Clusters in Two Dimensions Using PCA"

layout = dict(title = title,
              xaxis= dict(title= 'PC1',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'PC2',ticklen= 5,zeroline= False)
             )

fig = dict(data = data, layout = layout)

iplot(fig)
# Out:
# <div>                            <div id="f3d74bca-a687-49bb-9c9b-cfec27e7031b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3d74bca-a687-49bb-9c9b-cfec27e7031b")) {                    Plotly.newPlot(                        "f3d74bca-a687-49bb-9c9b-cfec27e7031b",                        [{"marker":{"color":"rgba(255, 128, 255, 0.8)"},"mode":"markers","name":"Cluster 0","x":[0.011432203146921092,-0.0006435318844604959,-0.00963825189789243,-0.010842400127345355,-0.010493325709726222,-0.006867396964291172,-0.0029860957253847655,-0.05231672096023409,-0.0033034577911567674,0.006341313895884997],"y":[0.01912862837325619,0.01633807387046556,0.011873962280040465,0.015063563602937865,0.013323033868870402,0.009985453618886479,0.010299605299008356,0.0248354
# ...

# %% [markdown]
# # Testing model on 5th December data

# %%
dfd2=pd.read_csv("D:/Time-varyying_PF_data/05-December-2022.csv")

# %%
header=["Timestamp", 'V1','V2', 'V3', 'A1', 'A2', 'A3', 'PA1', 'PA2', 'PA3', 'W1','W2', 'W3', 'VAR1', 'VAR2', 'VAR3', 'VA1', 'VA2', 'VA3', 'F', 'A12', 'A13', 'PF', 'Date', 'Time', 'DWh', 'DVARh', 'RWh', 'RVARh', 'TW', 'TVAR', 'TVA', 'TA', 'V12', 'V23', 'V31', 'THD1', 'THD2', 'THD3', 'THDA1', 'THDA2', 'THDA3', 'PF1', 'PF2', 'PF3']

dfd2.columns=header

# %%
dfpd2=dfd2.copy()
import datetime


dfpd2['Time'] = pd.to_datetime(dfd2['Timestamp'], unit='s', utc=False)
#dfp= dfp['Meter_Time'].dt.strftime('%d/%m/%Y %H:%M:%S')
#dfp['Date'] = pd.to_datetime(df1.Meter_Time, unit='s')
#dfp['Date']=dfp.Date.dt.strftime('%d/%m/%Y %H:%M:%S')

dfpd2['Time']=dfpd2['Time'].dt.tz_localize('UTC').dt.tz_convert('Asia/Singapore')

dfpd2['Time']= dfpd2['Time'].dt.strftime('%d/%m/%Y %H:%M:%S')
dfpd2[['Date','Time']]=dfpd2['Time'].str.split(' ', 1, expand=True)
dfpd2.columns
#2
dfpd2=dfpd2.drop(columns=['Date'])
df8c2=dfpd2['Time']
df9c2=dfpd2['Timestamp']
dfpd2=dfpd2.drop(columns=['Timestamp', 'Time']).astype('float')
dfpd2['Timestamp']=df9c2
dfpd2['Time']=df8c2


dfpd2['minutes']=dfpd2['Time'].str.split(':').apply(lambda x: int(x[0]) * 60 + int(x[1])+ (1/60)*int(x[2]))
dfpd2['minutes']

df_d1=dfpd2.copy()#dfpd2[(dfpd2['minutes']>=621.6) & (dfpd2['minutes']<=1075.56)]

a=df_d1['A1'].mean()
df_d1['demean-A1']=df_d1['A1']-a

# %%
df_d1["rolling_average_minutely"] = df_d1["A1"].rolling(window=60, min_periods=1).mean()

# %%
df_d1[[
    "A1",
    "rolling_average_minutely",
    ]].plot(color=['maroon', 'gold'],
            )
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
df_d2=dfpd2[(dfpd2['minutes']>=540.34) & (dfpd2['minutes']<=1104.7)]

# %%
df_d2["rolling_average_minutely"] = df_d2["A1"].rolling(window=60, min_periods=1).mean()
# Out:
# C:\Users\Varun Dhankhar\AppData\Local\Temp\ipykernel_16328\956532643.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_d2[[
    "rolling_average_minutely",
    ]].plot(color='gold',
            # xlim=["2012-11-11", "2012-11-12"],
           )
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
import ruptures as rpt
col=df_d2["rolling_average_minutely"].values

penalty = 3
algo = rpt.Pelt(model="l1").fit(col)
resultsd23 =  algo.predict(pen=penalty)

df_d2=df_d2.reset_index()

# %%
# %matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(col)
for i in resultsd23:
    num = col[i-1]
    ax.axvline(x = i, color = 'k', linestyle= "--")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
len(mod_results)
# Out:
# 34

# %%
len(results23)
# Out:
# 35

# %%
results23=[x - 1 for x in resultsd23]

# %%
import csv 
fields = ['Start_time', 'end_time', 'duration', 'mean', 'median', 'mode', 'minimum', 'maximum', 'std_dev', 'variance', 'kurtosis', 'skewness', 'energy', 'signal_mag_area'] 
global filename
filename = "state_statistics_day2.csv"

with open(filename, 'a') as csvfile:  # assigning column headers for the file of day1 only.
    writer = csv.writer(csvfile)
    writer.writerow(fields)
csvfile.close()


def write_csv_header(header):
    global filename
    with open(filename, 'a') as f:
        f.write("\n")
        f.write(header)
        
def states_day2():
    for value in range(0, len(results23)):
        if results23[value]!=results23[-1]:
            i=results23[value]
            j=results23[value+1]
            df_copy=df_d2.copy()
            data = ""
            start_time=df_d2.loc[i]['Timestamp']
            end_time=df_d2.loc[j]['Timestamp']
            duration=end_time-start_time
            data=str(start_time)+ "," +str(end_time)+ "," + str(duration)
            df_copy=df_copy[(df_copy['Timestamp']>=start_time) & (df_copy['Timestamp']<=end_time)]
            data=data + "," + str(df_copy['rolling_average_minutely'].mean()) + "," + str(df_copy['rolling_average_minutely'].median()) + "," + str(df_copy['rolling_average_minutely'].mode()[0]) + "," + str(df_copy['rolling_average_minutely'].min()) + "," + str(df_copy['rolling_average_minutely'].max()) + "," + str(df_copy['rolling_average_minutely'].std()) + "," + str(df_copy['rolling_average_minutely'].var()) + "," +  str(df_copy['rolling_average_minutely'].kurtosis()) + "," + str(df_copy['rolling_average_minutely'].skew())+ "," + str(df_copy['rolling_average_minutely'].apply(lambda x: np.sum(x**2)).mean())+ "," +str(df_copy['rolling_average_minutely'].apply(lambda x: np.sum(abs(x))).sum())
            write_csv_header(data)
            print(data)

# %%
states_day2()
# Out:
# 1670202144.27688,1670203321.3735876,1177.0967075824738,1.0030247706450846,1.0042667170365651,1.0089667151371637,0.9533833791812261,1.0143167128165562,0.008085586654448097,6.537671154658917e-05,11.842602715443753,-2.8657437572923965,1.0061240050348794,1054.1790339479844
# 1670203321.3735876,1670204539.9674258,1218.5938382148743,0.9103502248634495,0.9098500440518061,0.9078667104244232,0.8461000442504882,0.9577833821376165,0.009266405850147137,8.586627737964107e-05,17.154821222018718,-0.7821800867951753,0.8288233205495329,1006.8473486989736
# 1670204539.9674258,1670205319.067551,779.1001250743866,0.7799656489585661,0.7787417029341062,0.7767500350872676,0.7732833713293076,0.8461000442504882,0.008563536569985014,7.333415858547071e-05,31.338590472883755,5.403266099473896,0.6084196423487738,542.8560916751624
# ...

# %%
min_startd2=[]
min_endd2=[]
for value in range(0, len(results23)):
    if results23[value]!=results23[-1]:
        i=results23[value]
        j=results23[value+1]
        df_copy=df_d2.copy()
        min_startd2.append(df_d2.loc[i]['minutes'])
        min_endd2.append(df_d2.loc[j]['minutes'])

# %%
len(min_endd2)
# Out:
# 34

# %%
df_stats_day2=pd.read_csv("state_statistics_day2.csv")

dfst_d2=df_stats_day2.copy()
dfst_d2=dfst_d2.drop(['Start_time', 'end_time', 'std_dev', 'variance', 'kurtosis', 'skewness', 'duration', 'energy', 'signal_mag_area'], axis=1)

# %%
scaler = StandardScaler()
Xd2 = dfst_d2.values
scaled_Xd2 = scaler.fit_transform(Xd2)

# %%
clusters = kmeans.predict(Xd2)

# %%
clustXd2 = df_stats_day2.copy()
Xd22=dfst_d2.copy()

# %%
Xd22["Cluster"] = clusters
clustXd2["Cluster"] = clusters

# %%
clustXd2
# Out:
#       Start_time      end_time     duration      mean    median      mode  \
# 0   1.670202e+09  1.670203e+09  1177.096708  1.003025  1.004267  1.008967
# 1   1.670203e+09  1.670205e+09  1218.593838  0.910350  0.909850  0.907867
# 2   1.670205e+09  1.670205e+09   779.100125  0.779966  0.778742  0.776750
# 3   1.670205e+09  1.670206e+09   666.879405  0.771252  0.770467  0.769683
# 4   1.670206e+09  1.670206e+09   112.620700  0.885387  0.887000  0.891083
# 5   1.670206e+09  1.670207e+09  1173.081237  0.991588  0.992392  0.992033
# 6   1.670207e+09  1.670209e+09  1437.052397  0.897197  0.899700  0.900083
# 7   1.670209e+09  1.670210e+09  1180.631051  0.993837  0.993733  0.987100
# 8   1.670210e+09  1.670211e+09  1327.056226  0.896299  0.899133  0.900100
# 9   1.670211e+09  1.670212e+09  1175.579445  0.989234  0.990000  0.989183
# 10  1.670212e+09  1.670214e+09  1222.381900  0.896842  0.896867  0.895517
# 11  1.670214e+09  1.670214e+09   403.243493  0.769501  0.765350  0.764950
# ...

# %%
plotXd2 = Xd22
plotXd2.columns = Xd22.columns

# %%
clustXcopyd2=clustXd2.copy()

clustXcopyd2['min_start'] = np.array(min_startd2)
clustXcopyd2['min_end'] = np.array(min_endd2)

# %%
clustXcopyd2
# Out:
#       Start_time      end_time     duration      mean    median      mode  \
# 0   1.670202e+09  1.670203e+09  1177.096708  1.003025  1.004267  1.008967
# 1   1.670203e+09  1.670205e+09  1218.593838  0.910350  0.909850  0.907867
# 2   1.670205e+09  1.670205e+09   779.100125  0.779966  0.778742  0.776750
# 3   1.670205e+09  1.670206e+09   666.879405  0.771252  0.770467  0.769683
# 4   1.670206e+09  1.670206e+09   112.620700  0.885387  0.887000  0.891083
# 5   1.670206e+09  1.670207e+09  1173.081237  0.991588  0.992392  0.992033
# 6   1.670207e+09  1.670209e+09  1437.052397  0.897197  0.899700  0.900083
# 7   1.670209e+09  1.670210e+09  1180.631051  0.993837  0.993733  0.987100
# 8   1.670210e+09  1.670211e+09  1327.056226  0.896299  0.899133  0.900100
# 9   1.670211e+09  1.670212e+09  1175.579445  0.989234  0.990000  0.989183
# 10  1.670212e+09  1.670214e+09  1222.381900  0.896842  0.896867  0.895517
# 11  1.670214e+09  1.670214e+09   403.243493  0.769501  0.765350  0.764950
# ...

# %%
valdd2=pd.DataFrame()

valdd2['min_start']=clustXcopyd2['min_start']
valdd2['min_end']=clustXcopyd2['min_end']
valdd2['cluster']=clustXcopyd2['Cluster']

# %%
manuald2=[2, 0, 1, 1, 3, 2, 0, 2, 0, 2, 0, 1, 3, 2, 0, 1, 3, 2, 0, 1, 3, 2, 0, 2, 0, 2, 0, 2, 0, 2, 0, 1, 2, 0]

# %%
valdd2['manuald2']=np.array(manuald2)

# %%
valdd2
# Out:
#       min_start      min_end  cluster  manuald2
# 0    542.400000   562.016667        2         2
# 1    562.016667   582.316667        0         0
# 2    582.316667   595.316667        1         1
# 3    595.316667   606.416667        1         1
# 4    606.416667   608.300000        0         3
# 5    608.300000   627.850000        2         2
# 6    627.850000   651.800000        0         0
# 7    651.800000   671.483333        2         2
# 8    671.483333   693.600000        0         0
# 9    693.600000   713.183333        2         2
# 10   713.183333   733.566667        0         0
# 11   733.566667   740.283333        1         1
# 12   740.283333   750.033333        3         3
# 13   750.033333   769.766667        2         2
# 14   769.766667   790.133333        0         0
# 15   790.133333   795.000000        1         1
# 16   795.000000   799.550000        3         3
# 17   799.550000   819.250000        2         2
# 18   819.250000   839.683333        0         0
# ...

# %% [markdown]
# # One method to reduce the effect of CPD:

# %% [markdown]
# #to reduce effect if mean of current identified state from cpd and the next state is same upto 2nd decimal place than combine both of them into one state only.

# %%
import math
def truncate(f, n):
    n=2
    return math.floor(f * 10 ** n) / 10 ** n


mod_results=results23.copy()
lem=[]


for value in range(0, len(mod_results)-2):
    i=mod_results[value]
    j=mod_results[value+1]
    k=mod_results[value+2]
    df_copy_ij=df_d2.copy()
    df_copy_jk=df_d2.copy()
    start_time=df_d2.loc[i]['Timestamp']
    end_time_j=df_d2.loc[j]['Timestamp']
    end_time_k=df_d2.loc[k]['Timestamp']
    df_copy_ij=df_copy_ij[(df_copy_ij['Timestamp']>=start_time) & (df_copy_ij['Timestamp']<=end_time_j)]
    df_copy_jk=df_copy_jk[(df_copy_jk['Timestamp']>=end_time_j) & (df_copy_jk['Timestamp']<=end_time_k)]
    a=df_copy_ij['rolling_average_minutely'].mean()
    b=df_copy_jk['rolling_average_minutely'].mean()
    a=truncate(a, 2)
    b=truncate(b, 2)
    if a==b or abs(a-b)<0.02:
        lem.append(j)

# %%
lem
# Out:
# [2959]

# %%
for value in lem:
    mod_results.remove(value)

# %%
# %matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(col)
for i in mod_results:
    num = col[i-1]
    ax.axvline(x = i, color = 'k', linestyle= "--")
# Out:
# <img src="data:image/png;base64,..." width="800">
